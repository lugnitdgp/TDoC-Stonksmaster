# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot

# %%
x = df['LSTAT']
y=df['MEDV']
pyplot.plot(x,y)

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa8d4ac6128>,
# ...
#       dtype=object)
