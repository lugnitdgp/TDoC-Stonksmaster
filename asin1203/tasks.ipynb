# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('/content/drive/My Drive/housing.csv')

# %%
train.head(5)
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %% [markdown]
# LSTAT: Percentage of lower status of the population
#
# PTRATIO: Pupil-teacher ratio by town
#
# RM: Average number of rooms per dwelling
#
# MEDV: Median value of owner-occupied homes in $1000s

# %% [markdown]
# Conversion to 2-D array

# %%
train1 = pd.DataFrame(train['RM']).to_numpy() 
train1
# Out:
# array([[6.575],
#        [6.421],
#        [7.185],
#        [6.998],
#        [7.147],
#        [6.43 ],
#        [6.012],
#        [6.172],
#        [5.631],
#        [6.004],
#        [6.377],
#        [6.009],
#        [5.889],
#        [5.949],
#        [6.096],
#        [5.834],
#        [5.935],
#        [5.99 ],
#        [5.456],
#        [5.727],
#        [5.57 ],
#        [5.965],
#        [6.142],
#        [5.813],
#        [5.924],
#        [5.599],
#        [5.813],
#        [6.047],
#        [6.495],
#        [6.674],
#        [5.713],
#        [6.072],
#        [5.95 ],
#        [5.701],
#        [6.096],
#        [5.933],
#        [5.841],
#        [5.85 ],
#        [5.966],
#        [6.595],
#        [7.024],
#        [6.77 ],
#        [6.169],
#        [6.211],
#        [6.069],
#        [5.682],
#        [5.786],
#        [6.03 ],
#        [5.399],
#        [5.602],
#        [5.963],
#        [6.115],
#        [6.511],
#        [5.998],
#        [5.888],
# ...

# %%
train2 = pd.DataFrame(train['LSTAT']).to_numpy() 
train2
# Out:
# array([[ 4.98],
#        [ 9.14],
#        [ 4.03],
#        [ 2.94],
#        [ 5.33],
#        [ 5.21],
#        [12.43],
#        [19.15],
#        [29.93],
#        [17.1 ],
#        [20.45],
#        [13.27],
#        [15.71],
#        [ 8.26],
#        [10.26],
#        [ 8.47],
#        [ 6.58],
#        [14.67],
#        [11.69],
#        [11.28],
#        [21.02],
#        [13.83],
#        [18.72],
#        [19.88],
#        [16.3 ],
#        [16.51],
#        [14.81],
#        [17.28],
#        [12.8 ],
#        [11.98],
#        [22.6 ],
#        [13.04],
#        [27.71],
#        [18.35],
#        [20.34],
#        [ 9.68],
#        [11.41],
#        [ 8.77],
#        [10.13],
#        [ 4.32],
#        [ 1.98],
#        [ 4.84],
#        [ 5.81],
#        [ 7.44],
#        [ 9.55],
#        [10.21],
#        [14.15],
#        [18.8 ],
#        [30.81],
#        [16.2 ],
#        [13.45],
#        [ 9.43],
#        [ 5.28],
#        [ 8.43],
#        [14.8 ],
# ...

# %% [markdown]
# Dropping unnecessary columns

# %%
train_data=train.drop("PTRATIO",axis=1)
train_data.head(5)
# Out:
#       RM  LSTAT      MEDV
# 0  6.575   4.98  504000.0
# 1  6.421   9.14  453600.0
# 2  7.185   4.03  728700.0
# 3  6.998   2.94  701400.0
# 4  7.147   5.33  760200.0

# %% [markdown]
# Renaming Coloumns

# %%
train_data.rename(columns={'RM': 'Rooms/dwelling'}, inplace=True)
train_data.sample()
# Out:
#      Rooms/dwelling  LSTAT      MEDV
# 291           6.495   8.67  554400.0

# %%
train_data.rename(columns={'LSTAT': 'Lower-status Pop.(%)'}, inplace=True)
train_data.sample()
# Out:
#     Rooms/dwelling  Lower-status Pop.(%)      MEDV
# 78           6.232                 12.34  445200.0

# %%
train_data.rename(columns={'MEDV': 'Price(in $1000s)'}, inplace=True)
train_data.sample()
# Out:
#      Rooms/dwelling  Lower-status Pop.(%)  Price(in $1000s)
# 221           6.552                  3.76          661500.0

# %%
#Slicing
train_data_1=train_data.iloc[0:20] 
train_data_1
# Out:
#     Rooms/dwelling  Lower-status Pop.(%)  Price(in $1000s)
# 0            6.575                  4.98          504000.0
# 1            6.421                  9.14          453600.0
# 2            7.185                  4.03          728700.0
# 3            6.998                  2.94          701400.0
# 4            7.147                  5.33          760200.0
# 5            6.430                  5.21          602700.0
# 6            6.012                 12.43          480900.0
# 7            6.172                 19.15          569100.0
# 8            5.631                 29.93          346500.0
# 9            6.004                 17.10          396900.0
# 10           6.377                 20.45          315000.0
# 11           6.009                 13.27          396900.0
# 12           5.889                 15.71          455700.0
# 13           5.949                  8.26          428400.0
# 14           6.096                 10.26          382200.0
# ...

# %% [markdown]
# Task - 2

# %%
import matplotlib.pyplot as plt

# %%
x = train_data['Rooms/dwelling']
y = train_data['Price(in $1000s)']

# %%
colors = (0,0,0)
area = np.pi*3

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
