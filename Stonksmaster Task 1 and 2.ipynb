# %%
#importing modules

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
house=pd.read_csv(r"C:\Users\TISYAGUPTA PYNE\Downloads\housing.csv")

# %%
house
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
har=np.array(house).transpose()

# %%
har
#2d array made
# Out:
# array([[6.575e+00, 6.421e+00, 7.185e+00, ..., 6.976e+00, 6.794e+00,
#         6.030e+00],
#        [4.980e+00, 9.140e+00, 4.030e+00, ..., 5.640e+00, 6.480e+00,
#         7.880e+00],
#        [1.530e+01, 1.780e+01, 1.780e+01, ..., 2.100e+01, 2.100e+01,
#         2.100e+01],
#        [5.040e+05, 4.536e+05, 7.287e+05, ..., 5.019e+05, 4.620e+05,
#         2.499e+05]])

# %%
plt.plot(har[2],har[3])

plt.yscale('log')

plt.rcParams["figure.figsize"] =(20,10)

#plotting

# %%
from pandas import DataFrame as df

# %%
h=df(house)

# %%
h=h.iloc[0:,2:4] #slicing

# %%
h
#slicing done
# Out:
#      PTRATIO      MEDV
# 0       15.3  504000.0
# 1       17.8  453600.0
# 2       17.8  728700.0
# 3       18.7  701400.0
# 4       18.7  760200.0
# ..       ...       ...
# 484     21.0  470400.0
# 485     21.0  432600.0
# 486     21.0  501900.0
# 487     21.0  462000.0
# 488     21.0  249900.0
#
# [489 rows x 2 columns]

# %%
plt.plot(h)

# %%
h.plot(x='PTRATIO', y='MEDV', kind = 'scatter')

plt.yscale("log")

# %%
h
# Out:
#      PTRATIO      MEDV
# 0       15.3  504000.0
# 1       17.8  453600.0
# 2       17.8  728700.0
# 3       18.7  701400.0
# 4       18.7  760200.0
# ..       ...       ...
# 484     21.0  470400.0
# 485     21.0  432600.0
# 486     21.0  501900.0
# 487     21.0  462000.0
# 488     21.0  249900.0
#
# [489 rows x 2 columns]

# %%
h.rename(columns = {'PTRATIO':'col_1', 'MEDV':'col_2'}, inplace = True)

# %%
h

#columns renamed
# Out:
#      col_1     col_2
# 0     15.3  504000.0
# 1     17.8  453600.0
# 2     17.8  728700.0
# 3     18.7  701400.0
# 4     18.7  760200.0
# ..     ...       ...
# 484   21.0  470400.0
# 485   21.0  432600.0
# 486   21.0  501900.0
# 487   21.0  462000.0
# 488   21.0  249900.0
#
# [489 rows x 2 columns]

# %%
hh=np.array(h)
#converting to array

# %%
hh.transpose()#second time
# Out:
# array([[1.5300e+01, 1.7800e+01, 1.7800e+01, 1.8700e+01, 1.8700e+01,
#         1.8700e+01, 1.5200e+01, 1.5200e+01, 1.5200e+01, 1.5200e+01,
#         1.5200e+01, 1.5200e+01, 1.5200e+01, 2.1000e+01, 2.1000e+01,
#         2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01,
#         2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01,
#         2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01,
#         2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01, 2.1000e+01,
#         1.9200e+01, 1.9200e+01, 1.9200e+01, 1.9200e+01, 1.8300e+01,
#         1.8300e+01, 1.7900e+01, 1.7900e+01, 1.7900e+01, 1.7900e+01,
#         1.7900e+01, 1.7900e+01, 1.7900e+01, 1.7900e+01, 1.7900e+01,
#         1.6800e+01, 1.6800e+01, 1.6800e+01, 1.6800e+01, 2.1100e+01,
#         1.7900e+01, 1.7300e+01, 1.5100e+01, 1.9700e+01, 1.9700e+01,
#         1.9700e+01, 1.9700e+01, 1.9700e+01, 1.9700e+01, 1.8600e+01,
#         1.6100e+01, 1.6100e+01, 1.8900e+01, 1.8900e+01, 1.8900e+01,
# ...

# %%
plt.plot(hh)
#Task 2 done

plt.ylabel("col_2")
plt.xlabel("col_1")
# Out:
# Text(0.5, 0, 'col_1')

# %%
plt.plot(hh)
#second time

plt.ylabel("col_2")
plt.xlabel("col_1")
# Out:
# Text(0.5, 0, 'col_1')
