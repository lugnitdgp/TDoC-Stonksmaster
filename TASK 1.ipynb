# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('housing.csv')
sns.set_style('darkgrid')
print(df)
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %%
df.head(5)
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
import numpy as np
np_array = df.to_numpy()
display(np_array)
# Out:
# array([[6.575e+00, 4.980e+00, 1.530e+01, 5.040e+05],
#        [6.421e+00, 9.140e+00, 1.780e+01, 4.536e+05],
#        [7.185e+00, 4.030e+00, 1.780e+01, 7.287e+05],
#        ...,
#        [6.976e+00, 5.640e+00, 2.100e+01, 5.019e+05],
#        [6.794e+00, 6.480e+00, 2.100e+01, 4.620e+05],
#        [6.030e+00, 7.880e+00, 2.100e+01, 2.499e+05]])

# %%
df_data = df[['LSTAT', 'RM']].to_numpy()
df_data
# Out:
# array([[ 4.98 ,  6.575],
#        [ 9.14 ,  6.421],
#        [ 4.03 ,  7.185],
#        [ 2.94 ,  6.998],
#        [ 5.33 ,  7.147],
#        [ 5.21 ,  6.43 ],
#        [12.43 ,  6.012],
#        [19.15 ,  6.172],
#        [29.93 ,  5.631],
#        [17.1  ,  6.004],
#        [20.45 ,  6.377],
#        [13.27 ,  6.009],
#        [15.71 ,  5.889],
#        [ 8.26 ,  5.949],
#        [10.26 ,  6.096],
#        [ 8.47 ,  5.834],
#        [ 6.58 ,  5.935],
#        [14.67 ,  5.99 ],
#        [11.69 ,  5.456],
#        [11.28 ,  5.727],
#        [21.02 ,  5.57 ],
#        [13.83 ,  5.965],
#        [18.72 ,  6.142],
#        [19.88 ,  5.813],
#        [16.3  ,  5.924],
#        [16.51 ,  5.599],
#        [14.81 ,  5.813],
#        [17.28 ,  6.047],
#        [12.8  ,  6.495],
#        [11.98 ,  6.674],
#        [22.6  ,  5.713],
#        [13.04 ,  6.072],
#        [27.71 ,  5.95 ],
#        [18.35 ,  5.701],
#        [20.34 ,  6.096],
#        [ 9.68 ,  5.933],
#        [11.41 ,  5.841],
# ...

# %%
df_data1 = df.drop(['MEDV'], axis = 1) #The target variable, ‘MEDV’, will be the variable we seek to predict so drop that coloumn 
df_data1.head(5)
# Out:
#       RM  LSTAT  PTRATIO
# 0  6.575   4.98     15.3
# 1  6.421   9.14     17.8
# 2  7.185   4.03     17.8
# 3  6.998   2.94     18.7
# 4  7.147   5.33     18.7

# %%
df_data1.rename(columns = {'RM' : 'X', 'LSTAT' : 'Y', 'PTRATIO' : 'Z'}, inplace = True)
df_data1.sample()
# Out:
#          X      Y     Z
# 151  5.404  13.28  14.7

# %%
df_data1_1=df_data1.iloc[0:10] 
df_data1_1
# Out:
#        X      Y     Z
# 0  6.575   4.98  15.3
# 1  6.421   9.14  17.8
# 2  7.185   4.03  17.8
# 3  6.998   2.94  18.7
# 4  7.147   5.33  18.7
# 5  6.430   5.21  18.7
# 6  6.012  12.43  15.2
# 7  6.172  19.15  15.2
# 8  5.631  29.93  15.2
# 9  6.004  17.10  15.2
