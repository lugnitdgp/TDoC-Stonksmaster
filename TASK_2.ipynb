# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('housing.csv')

axis = plt.gca()

df.plot(kind='line',x='MEDV',y='LSTAT',ax=axis)
df.plot(kind='line',x='MEDV',y='PTRATIO', color='red', ax=axis)

plt.show()
