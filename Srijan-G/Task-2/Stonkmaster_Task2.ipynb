# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Importing the necessary libraries

# %%
df=pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df_values=df.values
print(df_values)
# Out:
# [[6.575e+00 4.980e+00 1.530e+01 5.040e+05]
#  [6.421e+00 9.140e+00 1.780e+01 4.536e+05]
#  [7.185e+00 4.030e+00 1.780e+01 7.287e+05]
#  ...
#  [6.976e+00 5.640e+00 2.100e+01 5.019e+05]
#  [6.794e+00 6.480e+00 2.100e+01 4.620e+05]
#  [6.030e+00 7.880e+00 2.100e+01 2.499e+05]]

# %%
sns.set_style('whitegrid')
X=df.iloc[:100,0]
y=df.iloc[:100,-1]
plt.figure(figsize=(10,5))
plt.plot(X,y)
plt.xlabel('RM')
plt.ylabel('MEDV')

plt.show()
# Line plot between RM and

# %%
X=df.iloc[:100,1]
y=df.iloc[:100,-1]
plt.figure(figsize=(10,5))
plt.plot(X,y)
plt.plot(X,y)
plt.xlabel('LSTAT')
plt.ylabel('MEDV')

plt.show()

# %%
X=df.iloc[:100,2]
y=df.iloc[:100,-1]
plt.figure(figsize=(10,5))
plt.plot(X,y)
plt.xlabel('PTRATIO')
plt.ylabel('MEDV')

plt.show()

# %% [markdown]
# From the line plots, we are not able to draw any inference about the data so we will try different types of plots to analyse the data

# %%
plt.plot(X,y,'.')
plt.xlabel('RM')
plt.ylabel('MEDV')

plt.show()
# Scatter plot to show the trend/relation between RM and Medv

# %%
X=df['LSTAT']
y=df['MEDV']
plt.figure(figsize=(10,5))
plt.plot(X,y,'.')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')

plt.show()

# %%
X=df['PTRATIO']
y=df['MEDV']
plt.figure(figsize=(10,5))
plt.plot(X,y,'.')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')

plt.show()

# %%
sns.distplot(df['RM'],kde=False)
# Histogram to show the distribution of data of a particular column
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['LSTAT'],kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['PTRATIO'],kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['MEDV'],kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(df.iloc[:100],diag_kind='hist')
#  Pair plot to show the realtionship between different columns for the first 100 values

# %%
sns.boxplot(y=df['RM'])
# Box plot to show quaterly data and outliers in the data

# %%
sns.boxplot(y=df['LSTAT'])

# %%
sns.boxplot(y=df['PTRATIO'])

# %%
sns.boxplot(y=df['MEDV'])

# %%
correlation=df.corr()['MEDV']
print(correlation)
# Function to show the correlation between other columns and MEDV
# Out:
# RM         0.697209
# LSTAT     -0.760670
# PTRATIO   -0.519034
# MEDV       1.000000
# Name: MEDV, dtype: float64

# %%
sns.heatmap(df.corr(),cmap='viridis')
# Heatmap to plot the correlation between different columns

# %%
sns.lmplot(data=df,x='RM',y='MEDV',aspect=2)
# Line plot which plots the best linear line of fit between  the x and y values

# %%
sns.lmplot(data=df,x='LSTAT',y='MEDV',aspect=2)

# %%
sns.lmplot(data=df,x='PTRATIO',y='MEDV',aspect=2)
