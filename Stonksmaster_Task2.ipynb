# %%
#importing modules

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("housing.csv")
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df.plot()

# %%
df.plot(x='PTRATIO',y='MEDV',kind='bar')

# %%
df['MEDV'].plot(kind='hist')

# %%
df.plot(figsize=(10,20),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029DB98D9E08>,
# ...
#       dtype=object)

# %%
df.plot(x='LSTAT',y='MEDV',kind='scatter')

# %%
df.plot(x='RM',y='MEDV',kind='scatter')

# %%
df.plot(x='PTRATIO',y='MEDV',kind='scatter')

# %%
df.plot.bar(figsize=(10,20),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000029DBA281E48>,
# ...
#       dtype=object)
