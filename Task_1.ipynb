# %% [markdown]
# Importing the libraries required

# %%
import numpy as np
import pandas as pd 
url = "https://raw.githubusercontent.com/Stellar-K/TDoC-Stonksmaster/Task_1/housing.csv"
df = pd.read_csv(url) 
print(df)
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %% [markdown]
# To understand relationships between data, scatter plots have been used.

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# We can spot a linear relationship between ‘RM’ and ‘MEDV’. RM seems to be normally distributed. MEDV also has a normal distribution but it has significant outliers.

# %% [markdown]
# Converting dataframe into 2D array:

# %%
arr2data = df.values
arr2data
# Out:
# array([[6.575e+00, 4.980e+00, 1.530e+01, 5.040e+05],
#        [6.421e+00, 9.140e+00, 1.780e+01, 4.536e+05],
#        [7.185e+00, 4.030e+00, 1.780e+01, 7.287e+05],
#        ...,
#        [6.976e+00, 5.640e+00, 2.100e+01, 5.019e+05],
#        [6.794e+00, 6.480e+00, 2.100e+01, 4.620e+05],
#        [6.030e+00, 7.880e+00, 2.100e+01, 2.499e+05]])

# %% [markdown]
# Slicing Data

# %%
df2 = df.loc[:, ['RM','MEDV']]
dataset = df2.values
dataset
# Out:
# array([[6.5750e+00, 5.0400e+05],
#        [6.4210e+00, 4.5360e+05],
#        [7.1850e+00, 7.2870e+05],
#        [6.9980e+00, 7.0140e+05],
#        [7.1470e+00, 7.6020e+05],
#        [6.4300e+00, 6.0270e+05],
#        [6.0120e+00, 4.8090e+05],
#        [6.1720e+00, 5.6910e+05],
#        [5.6310e+00, 3.4650e+05],
#        [6.0040e+00, 3.9690e+05],
#        [6.3770e+00, 3.1500e+05],
#        [6.0090e+00, 3.9690e+05],
#        [5.8890e+00, 4.5570e+05],
#        [5.9490e+00, 4.2840e+05],
#        [6.0960e+00, 3.8220e+05],
#        [5.8340e+00, 4.1790e+05],
#        [5.9350e+00, 4.8510e+05],
#        [5.9900e+00, 3.6750e+05],
#        [5.4560e+00, 4.2420e+05],
#        [5.7270e+00, 3.8220e+05],
#        [5.5700e+00, 2.8560e+05],
#        [5.9650e+00, 4.1160e+05],
#        [6.1420e+00, 3.1920e+05],
#        [5.8130e+00, 3.0450e+05],
#        [5.9240e+00, 3.2760e+05],
#        [5.5990e+00, 2.9190e+05],
#        [5.8130e+00, 3.4860e+05],
#        [6.0470e+00, 3.1080e+05],
# ...

# %% [markdown]
# Renaming columns

# %%
df2.rename(columns={'RM':'Avg No of Rooms per dwelling', 'MEDV':'Median Value of Owner Occupied Home'})
# Out:
#      Avg No of Rooms per dwelling  Median Value of Owner Occupied Home
# 0                           6.575                             504000.0
# 1                           6.421                             453600.0
# 2                           7.185                             728700.0
# 3                           6.998                             701400.0
# 4                           7.147                             760200.0
# ..                            ...                                  ...
# 484                         6.593                             470400.0
# 485                         6.120                             432600.0
# 486                         6.976                             501900.0
# 487                         6.794                             462000.0
# 488                         6.030                             249900.0
#
# [489 rows x 2 columns]
