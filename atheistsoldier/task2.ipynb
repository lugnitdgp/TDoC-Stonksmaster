# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot
df = pd.read_csv ('housing.csv')

arr=df.to_numpy()
df_new1=df.iloc[0:len(df),1:3]
df_new1.plot.line()

# %%
df_new2=df.iloc[0:len(df),2:4]
df_new2.plot.line()

# %%
df_new3=df.iloc[0:len(df),0:2]
df_new3.plot.line()

# %%
df_new4=df.loc[0:len(df),["PTRATIO","RM"]]
df_new4.plot.line()

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
